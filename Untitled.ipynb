# %%
# if u have not install tesseract use these commands 
# install it on system # you may dont need them all 
# sudo apt-get install -y tesseract-ocr  tesseract-ocr-eng tesseract-ocr-ara tesseract-ocr-hin

# %%
# !pip install pytesseract
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read image

# %%
img_path = 'idcard.jpeg'
img = cv2.imread(img_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) # convert image from BGR to RGB 
plt.imshow(img) ### show the image

# %% [markdown]
# ### filtering the image

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) # convert it to gray scale 
plt.imshow(gray,cmap='gray')

# %%
### using guassian filtring 
guassian_blurred = cv2.GaussianBlur(gray, (3, 3), 0) ### using guassian filtring 
plt.imshow(guassian_blurred,cmap='gray')

# %% [markdown]
# * as we see if the image resultion is greate so no need to do filtering

# %%
# find  edge usin the Canny edge detector 
original_edged  = cv2.Canny(img, 100, 255)
filterd_edged = cv2.Canny(guassian_blurred, 100, 255)
fig, ax = plt.subplots(nrows=1, ncols=2 , figsize =(10,10))

ax[0].set_title("filterd edged")
ax[1].set_title("original edged")

ax[0].imshow(filterd_edged,cmap='gray')
ax[1].imshow(original_edged,cmap='gray')
plt.show()

# %% [markdown]
# * each time we increase the kernel shape the edges descrease in the image
# * the image with high qaulity have a more edges than filterd image

# %%
plt.imshow(gray[100:115,155:265] , cmap = "gray")

# %%
print("Lang = Arabic : "+pytesseract.image_to_string(gray[100:115,155:265],lang='eng'))
print("Lang = english : "+pytesseract.image_to_string(gray[100:115,155:265],lang='eng'))
# Out:
# Lang = Arabic : 784-1977-1234566-1
#
# Lang = english : 784-1977-1234566-1

# %%
filterd_edged

# %%
import pytesseract

# %%
# Out:
#
#
#
#
#
#
#
#
# انلا

# %%
print(pytesseract.image_to_string(original_edged,lang='ara'))

print(pytesseract.image_to_string(filterd_edged,lang='ara'))
# Out:
#
#
#
#
#
#
#
#
# انلا
#
#
#
# ل ل ا 1
# 6 ليما 63 زالاسدق
#
#
#
# 0 -2
# ع - مم 5
#
# م 1 000006
# ل ل
# قيطت الحمري.

# %%
print(pytesseract.image_to_string(guassian_blurred,lang='ara'))
# Out:
# دولة الإمارات العربية المتجدة ومام امع طونم ماتدنا
# التلاقة شونة ممه بوالامموز
#
# قر حجح بير كه 686
#
# الإسم: احمد محمد عبد الله
#
#
#
# داانوطة ومجمهملا ممصهم مجماح
#
# الجنسية: الإمارات الغربية المتجدة
# وعام لمع ضوعم معثامنا. بااممموميم

# %%
print(pytesseract.image_to_string(gray,lang='ara'))
# Out:
# دولة الإمارات العربية المتحدة ةلمع ديم وعاتدنا
# بطاقة هوية لرانامو10
#
# 85 كنع إن سمد مره
# 784-17724566
#
# الإشم: احمد محمد عبد الله
#
#
#
# ا داانوطة لومو مالا فممطم :فجقلر
#
# ١
#
# 7 الجنسية: الإمارات الغربية المتجدة
# عام لمع ويم عالدنا الاللهممالهاة
